# %%
# %matplotlib inline

import pygal

# %%
chart = pygal.Bar(x_label_rotation=20)

chart.title = 'Comparison results of different approaches (Articles)'
chart.x_labels = ['Both side citations', 'Regarding affiliations', 'Regarding Main Path and COI calculatison']
chart.add('Number of nodes', [98, 68, 70])
chart.add('Number of edges', [58, 38, 39])
chart.add('Number of WCC',   [40, 30, 21])

# chart.render_in_browser()
chart.render_to_png('visualization/comparison_results_articles')

chart

# %%
chart = pygal.Bar(x_label_rotation=20)

chart.title = 'Comparison results of different approaches (Authors)'
chart.x_labels = ['Both side citations', 'Regarding affiliations', 'Regarding Main Path and COI calculatison']
chart.add('Number of nodes', [224, 118, 73])
chart.add('Number of edges', [502, 227, 137])
chart.add('Number of WCC',   [31, 28, 18])

# chart.render_in_browser()
chart.render_to_png('visualization/comparison_results_authors')

chart
