# %%
from db_dumps_and_entities.db_entities_and_session import db

# %%
@db_session
def commit_in_db(db_session, article_data):
    article_entity = db_session.Article.get(article_id=article_data['article_id'])
    
    if not article_entity:
        venue_entity = db_session.Venue.get(name=article_data['venue']['name'])
        if not venue_entity:
            venue_entity = db_session.Venue(name=article_data['venue']['name'])
        db_session.commit()
        venue_id = db_session.Venue.get(name=article_data['venue']['name']).venue_id

        db_session.Article(article_id=article_data['article_id'],
                           title=article_data['title'],
                           abstract=article_data['abstract'],
                           year=article_data['year'],
                           venue_id=venue_id)

        authors = article_data['authors']
        for author in authors:
            author_entity = db_session.Author.get(name=author['name'])
            if not author_entity:
                author_entity = db_session.Author(name=author['name'], url=author['url'])
            db_session.commit()
            author_id = db_session.Author.get(name=author['name']).author_id

            db_session.AuthorArticle(author_id=author_id, article_id=article_data['article_id'])

        for citation in article_data['cited_by']:
            citation_entity = db_session.Citation(article_id=article_data['article_id'], cited_by=citation)
        
        db_session.commit()
        
        print('Article with id {0} was added successfully ^-^'.format(article_data['article_id']))

# %%
event_parser = AcmDlListOfProceedingsParser()
proceeding_ids = event_parser.parse(misc.event_id, misc.client_id)
# Out:
# Starting parsing event with id: RE201
# Downloading event from url: https://dl.acm.org/event_series.cfm?id=RE201&_cf_containerId=cf_layoutareapubs&_cf_nodebug=true&_cf_nocache=true&_cf_clientid=77D09D38EC7423DB3CB517F4AAB87826&_cf_rc=1
# Successfully!!! ^_^

# %%
number_of_articles_in_event = 0

middle = 50

article_ids_nested = []

for proceeding_id in proceeding_ids[middle:]:
    print('Progress: {0}\{1}'.format(proceeding_ids.index(proceeding_id)+1, len(proceeding_ids)))
    
    proceeding_parser = AcmDlListOfArticlesParser()
    article_ids_in_proceeding = proceeding_parser.parse(proceeding_id)
    
    article_ids_nested.append(article_ids_in_proceeding)
    number_of_articles_in_event += len(article_ids_in_proceeding)
# Out:
# Progress: 51\100
# Starting parsing proceeding with id: 1181195
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1181195&preflayout=flat
# Successfully!!! ^_^
# Progress: 52\100
# Starting parsing proceeding with id: 1123058
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1123058&preflayout=flat
# Successfully!!! ^_^
# Progress: 53\100
# Starting parsing proceeding with id: 142868
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=142868&preflayout=flat
# Successfully!!! ^_^
# Progress: 54\100
# Starting parsing proceeding with id: 99277
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=99277&preflayout=flat
# Successfully!!! ^_^
# Progress: 55\100
# Starting parsing proceeding with id: 64135
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=64135&preflayout=flat
# Successfully!!! ^_^
# Progress: 56\100
# Starting parsing proceeding with id: 24208
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=24208&preflayout=flat
# Successfully!!! ^_^
# Progress: 57\100
# Starting parsing proceeding with id: 800020
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=800020&preflayout=flat
# Successfully!!! ^_^
# Progress: 58\100
# Starting parsing proceeding with id: 2660517
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2660517&preflayout=flat
# Successfully!!! ^_^
# Progress: 59\100
# Starting parsing proceeding with id: 1210525
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1210525&preflayout=flat
# Successfully!!! ^_^
# Progress: 60\100
# Starting parsing proceeding with id: 1108473
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1108473&preflayout=flat
# Successfully!!! ^_^
# Progress: 61\100
# Starting parsing proceeding with id: 3121252
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=3121252&preflayout=flat
# Successfully!!! ^_^
# Progress: 62\100
# Starting parsing proceeding with id: 2950290
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2950290&preflayout=flat
# Successfully!!! ^_^
# Progress: 63\100
# Starting parsing proceeding with id: 2635868
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2635868&preflayout=flat
# Successfully!!! ^_^
# Progress: 64\100
# Starting parsing proceeding with id: 2393596
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2393596&preflayout=flat
# Successfully!!! ^_^
# Progress: 65\100
# Starting parsing proceeding with id: 2025113
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2025113&preflayout=flat
# Successfully!!! ^_^
# Progress: 66\100
# Starting parsing proceeding with id: 1882291
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1882291&preflayout=flat
# Successfully!!! ^_^
# Progress: 67\100
# Starting parsing proceeding with id: 1453101
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1453101&preflayout=flat
# Successfully!!! ^_^
# Progress: 68\100
# Starting parsing proceeding with id: 1181775
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1181775&preflayout=flat
# Successfully!!! ^_^
# Progress: 69\100
# Starting parsing proceeding with id: 1029894
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1029894&preflayout=flat
# Successfully!!! ^_^
# Progress: 70\100
# Starting parsing proceeding with id: 587051
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=587051&preflayout=flat
# Successfully!!! ^_^
# Progress: 71\100
# Starting parsing proceeding with id: 355045
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=355045&preflayout=flat
# Successfully!!! ^_^
# Progress: 72\100
# Starting parsing proceeding with id: 288195
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=288195&preflayout=flat
# Successfully!!! ^_^
# Progress: 73\100
# Starting parsing proceeding with id: 239098
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=239098&preflayout=flat
# Successfully!!! ^_^
# Progress: 74\100
# Starting parsing proceeding with id: 222124
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=222124&preflayout=flat
# Successfully!!! ^_^
# Progress: 75\100
# Starting parsing proceeding with id: 193173
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=193173&preflayout=flat
# Successfully!!! ^_^
# Progress: 76\100
# Starting parsing proceeding with id: 256428
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=256428&preflayout=flat
# Successfully!!! ^_^
# Progress: 77\100
# Starting parsing proceeding with id: 125083
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=125083&preflayout=flat
# Successfully!!! ^_^
# Progress: 78\100
# Starting parsing proceeding with id: 800007
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=800007&preflayout=flat
# Successfully!!! ^_^
# Progress: 79\100
# Starting parsing proceeding with id: 1006147
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1006147&preflayout=flat
# Successfully!!! ^_^
# Progress: 80\100
# Starting parsing proceeding with id: 1596495
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1596495&preflayout=flat
# Successfully!!! ^_^
# Progress: 81\100
# Starting parsing proceeding with id: 1295074
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1295074&preflayout=flat
# Successfully!!! ^_^
# Progress: 82\100
# Starting parsing proceeding with id: 1188895
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1188895&preflayout=flat
# Successfully!!! ^_^
# Progress: 83\100
# Starting parsing proceeding with id: 2993283
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2993283&preflayout=flat
# Successfully!!! ^_^
# Progress: 84\100
# Starting parsing proceeding with id: 2804381
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2804381&preflayout=flat
# Successfully!!! ^_^
# Progress: 85\100
# Starting parsing proceeding with id: 2661685
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2661685&preflayout=flat
# Successfully!!! ^_^
# Progress: 86\100
# Starting parsing proceeding with id: 2501535
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2501535&preflayout=flat
# Successfully!!! ^_^
# Progress: 87\100
# Starting parsing proceeding with id: 2024645
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2024645&preflayout=flat
# Successfully!!! ^_^
# Progress: 88\100
# Starting parsing proceeding with id: 3121257
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=3121257&preflayout=flat
# Successfully!!! ^_^
# Progress: 89\100
# Starting parsing proceeding with id: 2989238
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2989238&preflayout=flat
# Successfully!!! ^_^
# Progress: 90\100
# Starting parsing proceeding with id: 1294917
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1294917&preflayout=flat
# Successfully!!! ^_^
# Progress: 91\100
# Starting parsing proceeding with id: 1595836
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1595836&preflayout=flat
# Successfully!!! ^_^
# Progress: 92\100
# Starting parsing proceeding with id: 3121264
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=3121264&preflayout=flat
# Successfully!!! ^_^
# Progress: 93\100
# Starting parsing proceeding with id: 2993259
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2993259&preflayout=flat
# Successfully!!! ^_^
# Progress: 94\100
# Starting parsing proceeding with id: 2501585
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2501585&preflayout=flat
# Successfully!!! ^_^
# Progress: 95\100
# Starting parsing proceeding with id: 2666990
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=2666990&preflayout=flat
# Successfully!!! ^_^
# Progress: 96\100
# Starting parsing proceeding with id: 1454268
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1454268&preflayout=flat
# Successfully!!! ^_^
# Progress: 97\100
# Starting parsing proceeding with id: 1137661
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1137661&preflayout=flat
# Successfully!!! ^_^
# Progress: 98\100
# Starting parsing proceeding with id: 1029997
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1029997&preflayout=flat
# Successfully!!! ^_^
# Progress: 99\100
# Starting parsing proceeding with id: 1075405
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=1075405&preflayout=flat
# Successfully!!! ^_^
# Progress: 100\100
# Starting parsing proceeding with id: 582128
# Downloading proceeding from url: https://dl.acm.org/citation.cfm?id=582128&preflayout=flat
# Successfully!!! ^_^

# %%
number_of_articles_in_event
# Out:
# 1152

# %%
article_ids = []

for ls in article_ids_nested:
    for article_id in ls:
        article_ids.append(article_id)
        
len(article_ids)
# Out:
# 1152

# %%
success_counter = 0

for article_id in article_ids[1100:]:
    print('Progress: {0}\{1}'.format(article_ids.index(article_id)+1, number_of_articles_in_event))
    try:
        article_parser = AcmDlArticleParser()
        article_data = article_parser.parse(article_id)
        commit_in_db(db, article_data)
        success_counter += 1
        print('\n\n')
    except Exception as e:
        print(str(e))
        print('Parsing article with id: {0} is not successful'.format(article_id))
print('{0} from {1} articles were parsed successfully'.format(success_counter, number_of_articles_in_event))
# Out:
# Progress: 1101\1152
# Start parsing article with id: 1030005
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030005&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
#
#
#
# Progress: 1102\1152
# Start parsing article with id: 1030007
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030007&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
#
#
#
# Progress: 1103\1152
# Start parsing article with id: 1030008
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030008&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
#
#
#
# Progress: 1104\1152
# Start parsing article with id: 1030009
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030009&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1030009 was added successfully ^-^
#
#
#
# Progress: 1105\1152
# Start parsing article with id: 1030011
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030011&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1030011 was added successfully ^-^
#
#
#
# Progress: 1106\1152
# Start parsing article with id: 1030012
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030012&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1030012 was added successfully ^-^
#
#
#
# Progress: 1107\1152
# Start parsing article with id: 1030013
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030013&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1030013 was added successfully ^-^
#
#
#
# Progress: 1108\1152
# Start parsing article with id: 1030014
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1030014&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1030014 was added successfully ^-^
#
#
#
# Progress: 1109\1152
# Start parsing article with id: 1075406
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075406&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075406 was added successfully ^-^
#
#
#
# Progress: 1110\1152
# Start parsing article with id: 1075407
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075407&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075407 was added successfully ^-^
#
#
#
# Progress: 1111\1152
# Start parsing article with id: 1075408
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075408&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075408 was added successfully ^-^
#
#
#
# Progress: 1112\1152
# Start parsing article with id: 1075409
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075409&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075409 was added successfully ^-^
#
#
#
# Progress: 1113\1152
# Start parsing article with id: 1075410
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075410&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075410 was added successfully ^-^
#
#
#
# Progress: 1114\1152
# Start parsing article with id: 1075411
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075411&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075411 was added successfully ^-^
#
#
#
# Progress: 1115\1152
# Start parsing article with id: 1075412
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075412&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075412 was added successfully ^-^
#
#
#
# Progress: 1116\1152
# Start parsing article with id: 1075413
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075413&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075413 was added successfully ^-^
#
#
#
# Progress: 1117\1152
# Start parsing article with id: 1075414
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075414&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075414 was added successfully ^-^
#
#
#
# Progress: 1118\1152
# Start parsing article with id: 1075415
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075415&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075415 was added successfully ^-^
#
#
#
# Progress: 1119\1152
# Start parsing article with id: 1075416
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075416&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075416 was added successfully ^-^
#
#
#
# Progress: 1120\1152
# Start parsing article with id: 1075417
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075417&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075417 was added successfully ^-^
#
#
#
# Progress: 1121\1152
# Start parsing article with id: 1075418
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075418&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075418 was added successfully ^-^
#
#
#
# Progress: 1122\1152
# Start parsing article with id: 1075419
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075419&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075419 was added successfully ^-^
#
#
#
# Progress: 1123\1152
# Start parsing article with id: 1075420
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075420&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075420 was added successfully ^-^
#
#
#
# Progress: 1124\1152
# Start parsing article with id: 1075421
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075421&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075421 was added successfully ^-^
#
#
#
# Progress: 1125\1152
# Start parsing article with id: 1075422
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075422&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075422 was added successfully ^-^
#
#
#
# Progress: 1126\1152
# Start parsing article with id: 1075423
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075423&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075423 was added successfully ^-^
#
#
#
# Progress: 1127\1152
# Start parsing article with id: 1075424
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075424&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075424 was added successfully ^-^
#
#
#
# Progress: 1128\1152
# Start parsing article with id: 1075425
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075425&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075425 was added successfully ^-^
#
#
#
# Progress: 1129\1152
# Start parsing article with id: 1075426
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075426&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075426 was added successfully ^-^
#
#
#
# Progress: 1130\1152
# Start parsing article with id: 1075427
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=1075427&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 1075427 was added successfully ^-^
#
#
#
# Progress: 1131\1152
# Start parsing article with id: 582130
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582130&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582130 was added successfully ^-^
#
#
#
# Progress: 1132\1152
# Start parsing article with id: 582131
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582131&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582131 was added successfully ^-^
#
#
#
# Progress: 1133\1152
# Start parsing article with id: 582132
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582132&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582132 was added successfully ^-^
#
#
#
# Progress: 1134\1152
# Start parsing article with id: 582133
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582133&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582133 was added successfully ^-^
#
#
#
# Progress: 1135\1152
# Start parsing article with id: 582134
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582134&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582134 was added successfully ^-^
#
#
#
# Progress: 1136\1152
# Start parsing article with id: 582135
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582135&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582135 was added successfully ^-^
#
#
#
# Progress: 1137\1152
# Start parsing article with id: 582136
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582136&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582136 was added successfully ^-^
#
#
#
# Progress: 1138\1152
# Start parsing article with id: 582137
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582137&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582137 was added successfully ^-^
#
#
#
# Progress: 1139\1152
# Start parsing article with id: 582138
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582138&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582138 was added successfully ^-^
#
#
#
# Progress: 1140\1152
# Start parsing article with id: 582139
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582139&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582139 was added successfully ^-^
#
#
#
# Progress: 1141\1152
# Start parsing article with id: 582140
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582140&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582140 was added successfully ^-^
#
#
#
# Progress: 1142\1152
# Start parsing article with id: 582141
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582141&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582141 was added successfully ^-^
#
#
#
# Progress: 1143\1152
# Start parsing article with id: 582142
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582142&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582142 was added successfully ^-^
#
#
#
# Progress: 1144\1152
# Start parsing article with id: 582143
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582143&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582143 was added successfully ^-^
#
#
#
# Progress: 1145\1152
# Start parsing article with id: 582144
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582144&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582144 was added successfully ^-^
#
#
#
# Progress: 1146\1152
# Start parsing article with id: 582146
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582146&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582146 was added successfully ^-^
#
#
#
# Progress: 1147\1152
# Start parsing article with id: 582147
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582147&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582147 was added successfully ^-^
#
#
#
# Progress: 1148\1152
# Start parsing article with id: 582148
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582148&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582148 was added successfully ^-^
#
#
#
# Progress: 1149\1152
# Start parsing article with id: 582149
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582149&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582149 was added successfully ^-^
#
#
#
# Progress: 1150\1152
# Start parsing article with id: 582150
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582150&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582150 was added successfully ^-^
#
#
#
# Progress: 1151\1152
# Start parsing article with id: 582151
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582151&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582151 was added successfully ^-^
#
#
#
# Progress: 1152\1152
# Start parsing article with id: 582152
# Initializing...
# Downloading article from url: https://dl.acm.org/citation.cfm?id=582152&preflayout=flat
# Getting authors...
# Getting abstract...
# Getting venue...
# Get citations...
# Successfully!!! ^_^
# Article with id 582152 was added successfully ^-^
#
#
#
# 52 from 1152 articles were parsed successfully

# %%
len(articles_data)
# Out:
# 1388

# %%
db.flush()
